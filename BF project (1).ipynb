# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for each year and ratio
data = {
    'Formula': [
        'Current Assets / Current Liabilities',
        '(Current Assets - Inventories) / Current Liabilities',
        'Cash and Cash Equivalents / Current Liabilities'
    ],
    '2019': [1.14, 0.40, 0.06],
    '2020': [1.10, 0.66, 0.43],
    '2021': [1.08, 0.65, 0.38],
    '2022': [1.13, 0.69, 0.57],
    '2023': [1.03, 0.43, 0.09]
}

# Row labels for the ratios
index_labels = ['Current Ratio', 'Quick Ratio', 'Cash Ratio']

# Creating the DataFrame
df = pd.DataFrame(data, index=index_labels)

# Dropping the 'Formula' column for plotting
df_numeric = df.drop(columns='Formula')

# Transposing for easier plotting (years as x-axis)
df_numeric = df_numeric.T

# Plotting the data
plt.figure(figsize=(10, 6))
for column in df_numeric.columns:
    plt.plot(df_numeric.index, df_numeric[column], marker='o', label=column)

# Adding titles and labels
plt.title("Liquidity Ratios Over Years (2019-2023)")
plt.xlabel("Year")
plt.ylabel("Ratio Value")
plt.legend(title="Ratio Type")
plt.grid(True)
plt.show()

# %%
# Data
years = ['2019', '2020', '2021', '2022', '2023']
gross_profit_margin = [1.70, 4.69, 5.10, 5.77, 16.92]
operating_profit_margin = [-2.47, 1.12, 2.93, 4.30, 10.67]
net_profit_margin = [-2.52, -1.67, 1.75, -4.52, -12.40]
return_on_assets = [-3.78, -1.95, 3.08, -8.44, -15.35]
asset_turnover = [150.36, 116.17, 176.44, 186.84, 123.81]
financial_leverage = [299.26, 274.35, 342.91, 556.81, 857.58]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Gross Profit Margin': gross_profit_margin,
    'Operating Profit Margin': operating_profit_margin,
    'Net Profit Margin': net_profit_margin,
    'Return on Assets': return_on_assets,
    'Asset Turnover': asset_turnover,
    'Financial Leverage': financial_leverage
})

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Gross Profit Margin'], marker='o', label='Gross Profit Margin')
plt.plot(df['Year'], df['Operating Profit Margin'], marker='o', label='Operating Profit Margin')
plt.plot(df['Year'], df['Net Profit Margin'], marker='o', label='Net Profit Margin')
plt.plot(df['Year'], df['Return on Assets'], marker='o', label='Return on Assets')
plt.plot(df['Year'], df['Asset Turnover'], marker='o', label='Asset Turnover')
plt.plot(df['Year'], df['Financial Leverage'], marker='o', label='Financial Leverage')

plt.title('Profitability Ratios (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 10))
fig.suptitle('Profitability Ratios (2019-2023)')

axes[0, 0].plot(df['Year'], df['Gross Profit Margin'], marker='o')
axes[0, 0].set_title('Gross Profit Margin')

axes[0, 1].plot(df['Year'], df['Operating Profit Margin'], marker='o')
axes[0, 1].set_title('Operating Profit Margin')

axes[1, 0].plot(df['Year'], df['Net Profit Margin'], marker='o')
axes[1, 0].set_title('Net Profit Margin')

axes[1, 1].plot(df['Year'], df['Return on Assets'], marker='o')
axes[1, 1].set_title('Return on Assets')

axes[2, 0].plot(df['Year'], df['Asset Turnover'], marker='o')
axes[2, 0].set_title('Asset Turnover')

axes[2, 1].plot(df['Year'], df['Financial Leverage'], marker='o')
axes[2, 1].set_title('Financial Leverage')

for ax in axes.flat:
    ax.set_xlabel('Year')
    ax.set_ylabel('Percentage')
    ax.grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
dupont_analysis = [-11.3, -5.3, 10.6, -47.0, -131.6]

# %%
df = pd.DataFrame({
    'Year': years,
    'Dupont Analysis': dupont_analysis
})

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Dupont Analysis'], marker='o', label='Dupont Analysis')
plt.title('Dupont Analysis (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
debt_to_equity_ratio = [0.0000, 0.0000, 0.0630, 0.0892, 0.1629]
times_interest_earned = [1, 1, 6, 1, 0]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Debt to Equity Ratio': debt_to_equity_ratio,
    'Times Interest Earned': times_interest_earned
})

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Debt to Equity Ratio'], marker='o', label='Debt to Equity Ratio')
plt.plot(df['Year'], df['Times Interest Earned'], marker='o', label='Times Interest Earned')
plt.title('Solvency Ratios (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
inventory_turnover_ratio = [1, 3, 7, 6, 2]
days_sales_outstanding = [794, 6, 2, 1, 6]
asset_turnover_ratio = [0, 1, 2, 2, 1]
pe_ratio = [-601.6, -1006.7, 743.1, -164.7, -207.2]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Inventory Turnover Ratio': inventory_turnover_ratio,
    'Days Sales Outstanding': days_sales_outstanding,
    'Asset Turnover Ratio': asset_turnover_ratio,
    'P/E Ratio': pe_ratio
})

# Plotting
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))
fig.suptitle('Efficiency and Market Ratios (2019-2023)')

axes[0, 0].plot(df['Year'], df['Inventory Turnover Ratio'], marker='o')
axes[0, 0].set_title('Inventory Turnover Ratio')

axes[0, 1].plot(df['Year'], df['Days Sales Outstanding'], marker='o')
axes[0, 1].set_title('Days Sales Outstanding')

axes[1, 0].plot(df['Year'], df['Asset Turnover Ratio'], marker='o')
axes[1, 0].set_title('Asset Turnover Ratio')

axes[1, 1].plot(df['Year'], df['P/E Ratio'], marker='o')
axes[1, 1].set_title('P/E Ratio')

for ax in axes.flat:
    ax.set_xlabel('Year')
    ax.set_ylabel('Ratio')
    ax.grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
total_assets = [77659826, 66647356, 91989970, 110084368, 84198381]
total_liabilities = [51708940, 42354915, 65163773, 90313820, 74380300]
total_equity = [25950886, 24292441, 26826197, 19770548, 9818081]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Total Assets': total_assets,
    'Total Liabilities': total_liabilities,
    'Total Equity': total_equity
})

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Total Assets'], marker='o', label='Total Assets')
plt.plot(df['Year'], df['Total Liabilities'], marker='o', label='Total Liabilities')
plt.plot(df['Year'], df['Total Equity'], marker='o', label='Total Equity')

plt.title('Total Assets, Liabilities, and Equity (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Data
years = ['2019', '2020', '2021', '2022', '2023']
data = {
    'Share Capital': [822999, 822999, 822999, 822999, 822999],
    'Capital & Other Reserves': [844596, 844596, 844596, 844596, 844596],
    'Revenue Reserves': [24283291, 22624846, 25158602, 18102953, 8150486],
    'Long-term Borrowing': [0, 0, 1689013, 1763301, 1599216],
    'Long-Term Lease Liabilities': [116192, 97485, 89022, 98252, 86024],
    'Others LT Liabilities': [399487, 658373, 1546068, 1777738, 1455697],
    'Trade & Others Payable': [18782224, 28977689, 61792126, 64147908, 60134299],
    'Short Term Borrowing': [32411037, 12621368, 0, 11321638, 0],
    'Current Portion Of Long Term Liabilities': [0, 47544, 114666, 210172, 0],
    'Current Taxation': [0, 0, 11090317, 10894892, 0],
    'PPE': [15685850, 13038601, 15544426, 14877495, 20351147],
    'Long Term Investments': [325925, 278160, 190492, 84551, 0],
    'Long Term Loans and Advances': [3500, 5152, 5553, 7498, 11346],
    'Long Term Deposits': [279304, 465068, 566714, 1034659, 762836],
    'Deferred Tax': [2359062, 6366126, 7345367, 7345367, 0],
    'Others LT Assets': [860966, 856711, 1273964, 1077582, 757436],
    'Store Spares & Loose Tools': [260424, 251828, 363922, 482775, 1303767],
    'Stock In Trade': [37516571, 17974242, 26225464, 33031769, 34908686],
    'Trade Debts': [690658, 503759, 197287, 385303, 1368972],
    'Loans & Advances': [55390, 119838, 164107, 1194060, 1686503],
    'Other Receivables': [16075362, 8969264, 16841633, 945748, 16713375],
    'Cash & Bank Balance': [3267510, 17818607, 23271041, 49617561, 6334313],
    'Sales': [116548013, 76720132, 160082255, 202466737, 102109380],
    'Cost of Sales': [114563486, 73120914, 151911517, 190782337, 84835572],
    'Administrative Expenses': [2550663, 1790825, 2480801, 2957069, 3893340],
    'Selling Cost & Distribution Cost': [2539251, 1639791, 2943268, 3217529, 2510162],
    'Other Operating Income': [222504, 704394, 2222665, 3211942, 2139116],
    'Other Operating Expenses': [-348, 15000, 279670, 8894, 2116956],
    'Finance Cost': [2087752, 2664734, 737041, 11614464, 10963737],
    'Provision For Taxation: Deferred': [-2128154, -1716626, -979241, 3194382, 10098630],
    'Provision For Taxation: Current': [96895, 1206687, 2095172, 3194382, 2753263]
}

df = pd.DataFrame(data, index=years)

# Vertical Analysis
vertical_analysis = df.div(df.sum(axis=1), axis=0) * 100

# Horizontal Analysis
horizontal_analysis = df.pct_change() * 100

# %%
print("Vertical Analysis:\n", vertical_analysis)
# Out:
# Vertical Analysis:
#        Share Capital  Capital & Other Reserves  Revenue Reserves  \
# 2019       0.210206                  0.215722          6.202305
# 2020       0.284295                  0.291755          7.815466
# 2021       0.159215                  0.163393          4.867110
# 2022       0.128450                  0.131821          2.825423
# 2023       0.217315                  0.223018          2.152160
#
#       Long-term Borrowing  Long-Term Lease Liabilities  Others LT Liabilities  \
# 2019             0.000000                     0.029677               0.102035
# 2020             0.000000                     0.033675               0.227427
# 2021             0.326752                     0.017222               0.299098
# 2022             0.275208                     0.015335               0.277461
# 2023             0.422278                     0.022715               0.384381
#
#       Trade & Others Payable  Short Term Borrowing  \
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows

# Data
years = ['2019', '2020', '2021', '2022', '2023']
data = {
    'Share Capital': [822999, 822999, 822999, 822999, 822999],
    'Capital & Other Reserves': [844596, 844596, 844596, 844596, 844596],
    'Revenue Reserves': [24283291, 22624846, 25158602, 18102953, 8150486],
    'Long-term Borrowing': [0, 0, 1689013, 1763301, 1599216],
    'Long-Term Lease Liabilities': [116192, 97485, 89022, 98252, 86024],
    'Others LT Liabilities': [399487, 658373, 1546068, 1777738, 1455697],
    'Trade & Others Payable': [18782224, 28977689, 61792126, 64147908, 60134299],
    'Short Term Borrowing': [32411037, 12621368, 0, 11321638, 0],
    'Current Portion Of Long Term Liabilities': [0, 47544, 114666, 210172, 0],
    'Current Taxation': [0, 0, 11090317, 10894892, 0],
    'PPE': [15685850, 13038601, 15544426, 14877495, 20351147],
    'Long Term Investments': [325925, 278160, 190492, 84551, 0],
    'Long Term Loans and Advances': [3500, 5152, 5553, 7498, 11346],
    'Long Term Deposits': [279304, 465068, 566714, 1034659, 762836],
    'Deferred Tax': [2359062, 6366126, 7345367, 7345367, 0],
    'Others LT Assets': [860966, 856711, 1273964, 1077582, 757436],
    'Store Spares & Loose Tools': [260424, 251828, 363922, 482775, 1303767],
    'Stock In Trade': [37516571, 17974242, 26225464, 33031769, 34908686],
    'Trade Debts': [690658, 503759, 197287, 385303, 1368972],
    'Loans & Advances': [55390, 119838, 164107, 1194060, 1686503],
    'Other Receivables': [16075362, 8969264, 16841633, 945748, 16713375],
    'Cash & Bank Balance': [3267510, 17818607, 23271041, 49617561, 6334313],
    'Sales': [116548013, 76720132, 160082255, 202466737, 102109380],
    'Cost of Sales': [114563486, 73120914, 151911517, 190782337, 84835572],
    'Administrative Expenses': [2550663, 1790825, 2480801, 2957069, 3893340],
    'Selling Cost & Distribution Cost': [2539251, 1639791, 2943268, 3217529, 2510162],
    'Other Operating Income': [222504, 704394, 2222665, 3211942, 2139116],
    'Other Operating Expenses': [-348, 15000, 279670, 8894, 2116956],
    'Finance Cost': [2087752, 2664734, 737041, 11614464, 10963737],
    'Provision For Taxation: Deferred': [-2128154, -1716626, -979241, 3194382, 10098630],
    'Provision For Taxation: Current': [96895, 1206687, 2095172, 3194382, 2753263]
}

df = pd.DataFrame(data, index=years)

# Vertical Analysis
vertical_analysis = df.div(df.sum(axis=1), axis=0) * 100

# Horizontal Analysis
horizontal_analysis = df.pct_change() * 100

# Create a workbook and add worksheets
wb = Workbook()

# Original Data
ws1 = wb.active
ws1.title = "Original Data"

for r in dataframe_to_rows(df, index=True, header=True):
    ws1.append(r)

# Vertical Analysis
ws2 = wb.create_sheet(title="Vertical Analysis")
for r in dataframe_to_rows(vertical_analysis, index=True, header=True):
    ws2.append(r)

# Horizontal Analysis
ws3 = wb.create_sheet(title="Horizontal Analysis")
for r in dataframe_to_rows(horizontal_analysis, index=True, header=True):
    ws3.append(r)

# Save the workbook
wb.save("financial_analysis.xlsx")

print("Analysis saved to 'financial_analysis.xlsx'")
# Out:
# Analysis saved to 'financial_analysis.xlsx'

# %%
import pandas as pd

# Define the financial data for each year
data = {
    '2019': [822999, 844596, 24283291, 0, 116192, 399487, 18782224, 0, 32411037, 0, 0, 15685850, 0, 325925, 3500, 279304, 2359062, 860966, 260424, 37516571, 690658, 55390, 16075362, 279304, 3267510],
    '2020': [822999, 844596, 22624846, 0, 97485, 658373, 28977689, 0, 12621368, 47544, 0, 13038601, 0, 278160, 5152, 465068, 6366126, 856711, 251828, 17974242, 503759, 119838, 8969264, 0, 17818607],
    '2021': [822999, 844596, 25158602, 0, 89022, 1546068, 61792126, 0, 0, 0, 0, 15544426, 0, 190492, 5553, 566714, 7345367, 1273964, 363922, 26225464, 197287, 164107, 16841633, 0, 23271041],
    '2022': [822999, 844596, 18102953, 0, 98252, 1777738, 64147908, 0, 11321638, 210172, 0, 14877495, 0, 84551, 7498, 1034659, 7345367, 1077582, 482775, 33031769, 385303, 1194060, 945748, 0, 49617561],
    '2023': [822999, 844596, 8150486, 0, 86024, 1455697, 60134299, 0, 0, 0, 0, 20351147, 0, 0, 11346, 762836, 0, 757436, 1303767, 34908686, 1368972, 1686503, 16713375, 0, 6334313]
}

# Define the row names (line items)
index = [
    'Share Capital', 'Capital & Other Reserves', 'Revenue Reserves', 
    'Surplus on Revaluation of Fixed Assets', 'Long-term Borrowing', 
    'Long-Term Lease Liabilities', 'Others', 'Trade & Others Payable', 
    'Interest & Markup', 'Short Term Borrowing', 'Current Portion Of Long Term Liabilities', 
    'Current Taxation', 'PPE', 'Investment Property', 'Long Term Investments', 
    'Long Term Loans and Advances', 'Long Term Deposits', 'Deferred Tax', 
    'Others', 'Store Spares & Loose Tools', 'Stock In Trade', 'Trade Debts', 
    'Loans & Advances', 'Other Receivables', 'Cash & Bank Balance'
]

# Create a DataFrame with the provided data
df = pd.DataFrame(data, index=index)

# Horizontal Analysis: Calculate percentage change from year to year
df_horizontal = df.pct_change(axis='columns') * 100

# Vertical Analysis: Calculate total assets for each year
df_total_assets = df.sum()

# Perform vertical analysis (percentage of total assets for each line item)
df_vertical = (df.div(df_total_assets, axis='columns')) * 100

# Display the results
print("Horizontal Analysis (Year-over-Year Percentage Changes):")
print(df_horizontal)
print("\nVertical Analysis (Percentage of Total Assets):")
print(df_vertical)
# Out:
# Horizontal Analysis (Year-over-Year Percentage Changes):
#                                           2019        2020        2021  \
# Share Capital                              NaN    0.000000    0.000000
# Capital & Other Reserves                   NaN    0.000000    0.000000
# Revenue Reserves                           NaN   -6.829573   11.198998
# Surplus on Revaluation of Fixed Assets     NaN         NaN         NaN
# Long-term Borrowing                        NaN  -16.100076   -8.681336
# Long-Term Lease Liabilities                NaN   64.804612  134.831623
# Others                                     NaN   54.282523  113.240352
# Trade & Others Payable                     NaN         NaN         NaN
# Interest & Markup                          NaN  -61.058426 -100.000000
# Short Term Borrowing                       NaN         inf -100.000000
# Current Portion Of Long Term Liabilities   NaN         NaN         NaN
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data
years = ['2019', '2020', '2021', '2022', '2023']
dupont_analysis = [-11.3, -5.3, 10.6, -47.0, -131.6]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Dupont Analysis': dupont_analysis
})

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Dupont Analysis'], marker='o', label='Dupont Analysis')
plt.title('Dupont Analysis (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
inventory_turnover_ratio = [1, 3, 7, 6, 2]
operating_ratio = [2, 2, 2, 2, 2]
dso = [2, 6, 2, 1, 6]  # Days Sales Outstanding
asset_turnover_ratio = [0, 1, 2, 2, 1]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Inventory Turnover Ratio': inventory_turnover_ratio,
    'Operating Ratio': operating_ratio,
    'Days Sales Outstanding': dso,
    'Asset Turnover Ratio': asset_turnover_ratio,

})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Inventory Turnover Ratio'], marker='o', label='Inventory Turnover Ratio')
plt.plot(df['Year'], df['Operating Ratio'], marker='o', label='Operating Ratio')
plt.plot(df['Year'], df['Days Sales Outstanding'], marker='o', label='Days Sales Outstanding')
plt.plot(df['Year'], df['Asset Turnover Ratio'], marker='o', label='Asset Turnover Ratio')


plt.title('Efficiency and Market Ratios (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data
years = ['2019', '2020', '2021', '2022', '2023']
current_ratio = [1.51, 1.54, 1.39, 1.29, 1.16]
quick_ratio = [0.53, 0.61, 0.51, 0.56, 0.55]
cash_ratio = [0.01, 0.01, 0.01, 0.00, 0.01]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Current Ratio': current_ratio,
    'Quick Ratio': quick_ratio,
    'Cash Ratio': cash_ratio
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Current Ratio'], marker='o', label='Current Ratio')
plt.plot(df['Year'], df['Quick Ratio'], marker='o', label='Quick Ratio')
plt.plot(df['Year'], df['Cash Ratio'], marker='o', label='Cash Ratio')

plt.title('Liquidity Ratios (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
gross_profit_margin = [7.47, 5.34, 8.75, 9.39, -3.72]
operating_profit_margin = [11.81, 4.51, 7.21, 5.33, 6.93]
net_profit_margin = [5.68, -2.07, 2.89, 0.80, 2.41]
roa = [5.28, -1.37, 2.65, 0.82, 1.92]  # Return on Assets

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Gross Profit Margin': gross_profit_margin,
    'Operating Profit Margin': operating_profit_margin,
    'Net Profit Margin': net_profit_margin,
    'Return on Assets (ROA)': roa
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Gross Profit Margin'], marker='o', label='Gross Profit Margin')
plt.plot(df['Year'], df['Operating Profit Margin'], marker='o', label='Operating Profit Margin')
plt.plot(df['Year'], df['Net Profit Margin'], marker='o', label='Net Profit Margin')
plt.plot(df['Year'], df['Return on Assets (ROA)'], marker='o', label='Return on Assets (ROA)')

plt.title('Profitability Ratios (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']

dupont_analysis = [14.7, -4.0, 7.6, 2.4, 5.2]  # Dupont Analysis

# Create DataFrame
df = pd.DataFrame({
    'Year': years,

    'Dupont Analysis': dupont_analysis
})

# Plotting
plt.figure(figsize=(14, 8))

plt.plot(df['Year'], df['Dupont Analysis'], marker='o', label='Dupont Analysis')

plt.title('Profitability Ratios and Dupont Analysis (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
inventory_turnover_ratio = [0, 4, 5, 6, 5]
dso = [4008, 47, 34, 32, 45]  # Days Sales Outstanding
pe_ratio = [229.3, -10.2, 2.5, 4.0, 5.2]  # Price-to-Earnings (P/E) Ratio

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'P/E Ratio': pe_ratio
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['P/E Ratio'], marker='o', label='P/E Ratio')

plt.title('Efficiency and Market Ratios (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
inventory_turnover_ratio = [0, 4, 5, 6, 5]
df = pd.DataFrame({'Year': years,'Inventory Turnover Ratio': inventory_turnover_ratio})
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Inventory Turnover Ratio'], marker='o', label='Inventory Turnover Ratio')
plt.title(' Inventory Turnover Ratio(2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
dso = [4008, 47, 34, 32, 45]
df = pd.DataFrame({'Year': years,'Days Sales Outstanding': dso})
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Days Sales Outstanding'], marker='o', label='Days Sales Outstanding')
plt.title(' Days Sales Outstanding(2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
debt_to_equity_ratio = [0.7872, 0.8085, 0.6983, 0.6062, 0.6012]
times_interest_earned = [4, 1, 1, 0, 3]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Debt to Equity Ratio': debt_to_equity_ratio,
    'Times Interest Earned': times_interest_earned
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Debt to Equity Ratio'], marker='o', label='Debt to Equity Ratio')
plt.plot(df['Year'], df['Times Interest Earned'], marker='o', label='Times Interest Earned')

plt.title('Solvency Ratios (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
quick_ratio = [0.51, 0.29, 0.48, 0.65, 0.54]
cash_ratio = [0.00, 0.00, 0.01, 0.01, 0.01]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Quick Ratio': quick_ratio,
    'Cash Ratio': cash_ratio
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Quick Ratio'], marker='o', label='Quick Ratio')
plt.plot(df['Year'], df['Cash Ratio'], marker='o', label='Cash Ratio')

plt.title('Quick Ratio and Cash Ratio (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
gross_profit_margin = [12.42, 11.79, 18.20, 20.93, 9.74]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Gross Profit Margin': gross_profit_margin
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Gross Profit Margin'], marker='o', label='Gross Profit Margin')

plt.title('Gross Profit Margin (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
operating_profit_margin = [14.86, 9.45, 16.27, 17.02, 7.88]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Operating Profit Margin': operating_profit_margin
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Operating Profit Margin'], marker='o', label='Operating Profit Margin')

plt.title('Operating Profit Margin (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
net_profit_margin = [7.58, -1.67, 10.14, 11.90, -1.46]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Net Profit Margin': net_profit_margin
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Net Profit Margin'], marker='o', label='Net Profit Margin')

plt.title('Net Profit Margin (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
roe = [20.65, -4.44, 26.77, 30.43, -4.82]  # Return on Equity (ROE)

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Return on Equity (ROE)': roe
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Return on Equity (ROE)'], marker='o', label='Return on Equity (ROE)')

plt.title('Return on Equity (ROE) (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
debt_to_equity_ratio = [0.2384, 0.4403, 0.3371, 0.5476, 0.6055]
times_interest_earned = [1, 0, 0, 0, 0]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Debt to Equity Ratio': debt_to_equity_ratio,
    'Times Interest Earned': times_interest_earned
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Debt to Equity Ratio'], marker='o', label='Debt to Equity Ratio')
plt.plot(df['Year'], df['Times Interest Earned'], marker='o', label='Times Interest Earned')

plt.title('Solvency Ratios (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
debt_to_equity_ratio = [0.2384, 0.4403, 0.3371, 0.5476, 0.6055]

# Create DataFrame
df_debt_to_equity = pd.DataFrame({
    'Year': years,
    'Debt to Equity Ratio': debt_to_equity_ratio
})

# Plotting Debt to Equity Ratio
plt.figure(figsize=(14, 8))
plt.plot(df_debt_to_equity['Year'], df_debt_to_equity['Debt to Equity Ratio'], marker='o', label='Debt to Equity Ratio')

plt.title('Debt to Equity Ratio (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
times_interest_earned = [1, 0, 0, 0, 0]

# Create DataFrame
df_times_interest_earned = pd.DataFrame({
    'Year': years,
    'Times Interest Earned': times_interest_earned
})

# Plotting Times Interest Earned
plt.figure(figsize=(14, 8))
plt.plot(df_times_interest_earned['Year'], df_times_interest_earned['Times Interest Earned'], marker='o', label='Times Interest Earned')

plt.title('Times Interest Earned (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
inventory_turnover_ratio = [0, 2, 2, 2, 3]
dso = [2406, 114, 85, 86, 103]  # Days Sales Outstanding

# Create DataFrames
df_inventory_turnover = pd.DataFrame({
    'Year': years,
    'Inventory Turnover Ratio': inventory_turnover_ratio
})

df_dso = pd.DataFrame({
    'Year': years,
    'Days Sales Outstanding': dso
})

# Plotting Inventory Turnover Ratio
plt.figure(figsize=(14, 8))
plt.plot(df_inventory_turnover['Year'], df_inventory_turnover['Inventory Turnover Ratio'], marker='o', label='Inventory Turnover Ratio')
plt.title('Inventory Turnover Ratio (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting Days Sales Outstanding (DSO)
plt.figure(figsize=(14, 8))
plt.plot(df_dso['Year'], df_dso['Days Sales Outstanding'], marker='o', label='Days Sales Outstanding')
plt.title('Days Sales Outstanding (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Days')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
pe_ratio = [2.4, -20.6, 2.2, 0.7, -6.0]  # Price-to-Earnings (P/E) Ratio

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'P/E Ratio': pe_ratio
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['P/E Ratio'], marker='o', label='P/E Ratio')

plt.title('Price-to-Earnings (P/E) Ratio (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
quick_ratio = [0.53, 0.39, 0.33, 0.27, 0.24]
cash_ratio = [0.09, 0.07, 0.06, 0.06, 0.00]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Quick Ratio': quick_ratio,
    'Cash Ratio': cash_ratio
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Quick Ratio'], marker='o', label='Quick Ratio')
plt.plot(df['Year'], df['Cash Ratio'], marker='o', label='Cash Ratio')

plt.title('Quick Ratio and Cash Ratio (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
gross_profit_margin = [14.40, 32.47, 32.07, 25.82, 29.13]
operating_profit_margin = [7.33, 4.38, 17.94, 19.83, 20.17]
net_profit_margin = [-141.62, -437.49, -111.54, -55.34, -143.44]
roa = [-7.36, -8.72, -5.03, -5.79, -10.21]  # Return on Assets (ROA)

# Create DataFrames
df_gross_profit = pd.DataFrame({
    'Year': years,
    'Gross Profit Margin': gross_profit_margin
})

df_operating_profit = pd.DataFrame({
    'Year': years,
    'Operating Profit Margin': operating_profit_margin
})

df_net_profit = pd.DataFrame({
    'Year': years,
    'Net Profit Margin': net_profit_margin
})

df_roa = pd.DataFrame({
    'Year': years,
    'Return on Assets (ROA)': roa
})

# Plotting Gross Profit Margin
plt.figure(figsize=(14, 8))
plt.plot(df_gross_profit['Year'], df_gross_profit['Gross Profit Margin'], marker='o', label='Gross Profit Margin')
plt.title('Gross Profit Margin (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 8))
plt.plot(df_operating_profit['Year'], df_operating_profit['Operating Profit Margin'], marker='o', label='Operating Profit Margin')
plt.title('Operating Profit Margin (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 8))
plt.plot(df_net_profit['Year'], df_net_profit['Net Profit Margin'], marker='o', label='Net Profit Margin')
plt.title('Net Profit Margin (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 8))
plt.plot(df_roa['Year'], df_roa['Return on Assets (ROA)'], marker='o', label='Return on Assets (ROA)')
plt.title('Return on Assets (ROA) (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
dupont_analysis = [-31.5, -47.2, -32.9, -49.5, -251.7]

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Dupont Analysis': dupont_analysis
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Dupont Analysis'], marker='o', label='Dupont Analysis')

plt.title('Dupont Analysis (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
debt_to_equity_ratio = [1.0121, 0.9477, 0.6780, 0.3586, 0.1713]
times_interest_earned = [0, 0, 0, 0, 0]

# Create DataFrames
df_debt_to_equity = pd.DataFrame({
    'Year': years,
    'Debt to Equity Ratio': debt_to_equity_ratio
})

df_times_interest_earned = pd.DataFrame({
    'Year': years,
    'Times Interest Earned': times_interest_earned
})

# Plotting Debt to Equity Ratio
plt.figure(figsize=(14, 8))
plt.plot(df_debt_to_equity['Year'], df_debt_to_equity['Debt to Equity Ratio'], marker='o', label='Debt to Equity Ratio')
plt.title('Debt to Equity Ratio (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting Times Interest Earned
plt.figure(figsize=(14, 8))
plt.plot(df_times_interest_earned['Year'], df_times_interest_earned['Times Interest Earned'], marker='o', label='Times Interest Earned')
plt.title('Inventory turnover(2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
dso = [211, 0, 0, 15, 159]  # Days Sales Outstanding

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'Days Sales Outstanding': dso
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['Days Sales Outstanding'], marker='o', label='Days Sales Outstanding')

plt.title('Days Sales Outstanding (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Days')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2019', '2020', '2021', '2022', '2023']
pe_ratio = [-0.5, -0.4, -0.7, -0.6, -0.4]  # Market Price per Share / Earnings per Share

# Create DataFrame
df = pd.DataFrame({
    'Year': years,
    'P/E Ratio': pe_ratio
})

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(df['Year'], df['P/E Ratio'], marker='o', label='P/E Ratio')

plt.title('Price-to-Earnings (P/E) Ratio (2019-2023)')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
